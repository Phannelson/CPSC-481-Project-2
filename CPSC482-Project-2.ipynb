# %% [markdown]
# # Project 2
# ## Group Members
# - Eulices Martinez de la cruz
# - Aaron Lee
# - Nelson Phan
# - Abel Mendoza
# - James Thyen
#
#
# ### Friends:
# 1. Glaydys
# 2. Lillie
# 3. Pam
# 4. Victor
# ### Years:
#
# 1. 2001
# 2. 2002
# 3. 2003
# 4. 2004
#
# ### Activities:
#
# 1. Camping
# 2. Hang gliding
# 3. Kayaking
# 4. Skydiving
#
# ### Clues:
#
# 1. The friend that went skydiving took their trip 2 years before the friend who went hang gliding.
# 2. Gladys either went kayaking or went on vacation in 2004.
# 3. Lillie went on vacation in 2003.
# 4. The four trips are: Lillie in 2003, the hang gliding trip, the vacation with Victor, and one with Gladys.
# ### Inferred data
# 1. The person who went skydiving had to take their trip in 2001 or 2002.
# #### Let Gladys = G, Lille = L, Pam = P, Victor = VI
# #### Let Camping = C, Hang gliding = HG, Kayaking = KY, Skydiving = SD
# * 𝐿 ∧2003
# * 𝐾𝑌 ¬2004
# * 𝑆𝐷 ¬2003
# * 𝑆𝐷,𝐻𝐺 ¬2003 ↔𝐻𝐺 ∧ 2004
# * 𝑆𝐷 ¬2004
# * 𝐻𝐺 ¬2001
# * 𝐻𝐺 ¬2002
# * 𝐻𝐺 ¬2003
# * 𝐻𝐺 ⋀2004
# * 𝑆𝐷 ⋏2002
# * 𝐻𝐺 ¬𝑉𝐼 𝐺 ¬𝐻𝐺 ¬2003 ¬2002 ¬2001
# * *𝐿 ¬2002 ¬𝑆𝐷
# * 𝐿 ⋏2003 ¬𝐻𝐺
# * 𝑃 ⋏𝐻𝐺
# * 𝑃 ⋏𝐻𝐺 ⋏2004
# * 𝐺∧𝐾𝑌 ¬2004
# * 𝐿 ⋀𝐶
# * 𝑉𝐼 ⋏ 𝑆𝐷
# * 𝑉𝐼 ∧2002
# * 𝐺 ∧ 2001
# * 𝐺 ∧ 2001 ∧𝐾𝑌
