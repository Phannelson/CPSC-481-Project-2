# %% [markdown]
# # Project 2
# ## Group Members
# - Eulices Martinez de la cruz
# - Aaron Lee
# - Nelson Phan
#
# ### Friends:
# 1. Glaydys
# 2. Lillie
# 3. Pam
# 4. Victor
# ### Years:
#
# 1. 2001
# 2. 2002
# 3. 2003
# 4. 2004
#
# ### Activities:
#
# 1. Camping
# 2. Hang gliding
# 3. Kayaking
# 4. Skydiving
#
# ### Clues:
#
# 1. The friend that went skydiving took their trip 2 years before the friend who went hang gliding. || SD ∧ YR ↔ HG ∧ YR+2: The skydiving trip in year YR implies the hang gliding vacation was 2 years later in YR+2.
# 2. Gladys either went kayaking or went on vacation in 2004. || G ∧ (KY ∨ 2004): The holiday with Gladys was either the kayaking vacation or the 2004 holiday.
# 3. Lillie went on vacation in 2003. || L ∧ 2003: The trip with Lillie was in 2003.
# 4. The four trips are: Lillie in 2003, the hang gliding trip, the vacation with Victor, and one with Gladys. || 2003 ∧ HG ∧ VI ∧ G: The four trips are the 2003 trip, the Hang gliding trip, the vacation with Victor, and the holiday with Gladys.
# ### Inferred data
#
# #### Let Gladys = G, Lille = L, Pam = P, Victor = VI
# #### Let Camping = C, Hang gliding = HG, Kayaking = KY, Skydiving = SD
#
# Activity x Year:
#
# * HG ∧ ¬2001: The hang gliding trip did not happen in 2001.
# * HG ∧ ¬2002: The hang gliding trip did not happen in 2002.
# * HG ∧ ¬2003: The hang gliding trip did not happen in 2003.
# * HG ∧ 2004: The hang gliding trip happened in 2004.
# * SD ∧ ¬2001: The skydiving trip did not happen in 2001.
# * SD ∧ 2002: The skydiving trip happened in 2002.
# * SD ∧ ¬2003: The skydiving trip did not happen in 2003.
# * SD ∧ ¬2004: The skydiving trip did not happen in 2004.
# * KY ∧ ¬2004: The kayaking trip did not happen in 2004.
# * KY ∧ ¬2003: The kayaking trip did not happen in 2003.
# * KY ∧ ¬2002: The kayaking trip did not happen in 2002.
# * KY ∧ 2001: The kayaking trip happened in 2001.
# * C ∧ 2003: The camping trip happened in 2003.
# * C ∧ ¬2001: The camping trip did not happen in 2001.
# * C ∧ ¬2002: The camping trip did not happen in 2002.
# * C ∧ ¬2004: The camping trip did not happen in 2004.
#
# Friend x Trip:
#
# * G ∧ KY: Gladys went kayaking.
# * G ∧ ¬HG: Gladys did not go hang gliding.
# * G ∧ ¬SD: Gladys did not go skydiving.
# * G ∧ ¬C: Gladys did not go camping.
# * P ∧ HG: Pam went hang gliding.
# * P ∧ ¬SD: Pam did not go skydiving.
# * P ∧ ¬C: Pam did not go camping.
# * P ∧ ¬KY: Pam did not go kayaking.
# * L ∧ C: Lillie went camping.
# * L ∧ ¬HG: Lillie did not go hang gliding.
# * L ∧ ¬SD: Lillie did not go skydiving.
# * L ∧ ¬KY: Lillie did not go kayaking.
# * VI ∧ SD: Victor went skydiving.
# * VI ∧ ¬HG: Victor did not go hang gliding.
# * VI ∧ ¬C: Victor did not go camping.
# * VI ∧ ¬KY: Victor did not go kayaking.
#
# Friend x Year:
# * P ∧ ¬2001: Pam did not go on a trip in 2001.
# * P ∧ ¬2002: Pam did not go on a trip in 2002.
# * P ∧ ¬2003: Pam did not go on a trip in 2003.
# * P ∧ 2004: Pam went on a trip in 2004.
# * G ∧ 2001: Gladys went on a trip in 2001.
# * G ∧ ¬2002: Gladys did not go on a trip in 2002.
# * G ∧ ¬2003: Gladys did not go on a trip in 2003.
# * G ∧ ¬2004: Gladys did not go on a trip in 2004.
# * L ∧ 2003: Lillie went on a trip in 2003.
# * L ∧ ¬2001: Lillie did not go on a trip in 2001.
# * L ∧ ¬2002: Lillie did not go on a trip in 2002.
# * L ∧ ¬2004: Lillie did not go on a trip in 2004.
# * VI ∧ 2002: Victor went on a trip in 2002.
# * VI ∧ ¬2001: Victor did not go on a trip in 2001.
# * VI ∧ ¬2003: Victor did not go on a trip in 2003.
# * VI ∧ ¬2004: Victor did not go on a trip in 2004.
